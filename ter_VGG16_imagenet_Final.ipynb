Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=u4B3%7EZuvgEVorPaD%7E%7EckLJohLDSbzyk6Dveny3fe6Gx-aG1e7XE6xBJYDUUqbw5mJWDcUgU%7EbmrNHZbEvLaW5e2K920683dzt%7ETdZ9n2qhK3FO-FrKb2sZudtIo1A687lSqufrt27RVz3FS0mx8orRtSVmddzD7Ve6jXu0v8YFXOC6HkpVm1zeBMro3qcRSJ317jyAcAKgAv87hNV7d3Gktu0JqZrzv%7EqEOWaUV-CIbPLkaHgx7%7EEJIB55TEK9b-dvQcDvDM7ROcf2inHet%7EkWHGV4xW2YdaL7B3SS8vJp6zMj5cjFHSeTWQWNWqe1egg42CdfPk3yvXRNRDW5XiOA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-05-12 18:10:28--  https://cdn-lfs.huggingface.co/repos/43/54/4354080778713efff252f32d0ea8cda241f8af84fe016fdd4e0d57db34b94861/e83b55d6692d54e5aad38427531fa831bf30d1051ccc4267d4db90f03aaa7136?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27wiki.zip%3B+filename%3D%22wiki.zip%22%3B&response-content-type=application%2Fzip&Expires=1715796628&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qJnJlc3BvbnNlLWNvbnRlbnQtdHlwZT0qIn1dfQ__&Signature=u4B3%7EZuvgEVorPaD%7E%7EckLJohLDSbzyk6Dveny3fe6Gx-aG1e7XE6xBJYDUUqbw5mJWDcUgU%7EbmrNHZbEvLaW5e2K920683dzt%7ETdZ9n2qhK3FO-FrKb2sZudtIo1A687lSqufrt27RVz3FS0mx8orRtSVmddzD7Ve6jXu0v8YFXOC6HkpVm1zeBMro3qcRSJ317jyAcAKgAv87hNV7d3Gktu0JqZrzv%7EqEOWaUV-CIbPLkaHgx7%7EEJIB55TEK9b-dvQcDvDM7ROcf2inHet%7EkWHGV4xW2YdaL7B3SS8vJp6zMj5cjFHSeTWQWNWqe1egg42CdfPk3yvXRNRDW5XiOA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.25.122, 18.65.25.124, 18.65.25.40, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.25.122|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1766572515 (1.6G) [application/zip]
# Saving to: ‘wiki.zip’
#
# wiki.zip            100%[===================>]   1.64G  47.2MB/s    in 34s
#
# 2024-05-12 18:11:03 (49.5 MB/s) - ‘wiki.zip’ saved [1766572515/1766572515]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -q inpainting.zip
# !unzip -q wiki.zip


# !rm -r inpainting.zip
# !rm -r wiki.zip

# %%
import os
import shutil

def copy_images(source_folder, destination_folder):
    # Create the destination folder if it doesn't exist
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Walk through each subfolder in the source folder
    for root, dirs, files in os.walk(source_folder):
        for file in files:
            # Check if the file is an image
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.gif')):
                # Get the full path of the image
                source_path = os.path.join(root, file)
                # Copy the image to the destination folder
                shutil.copy(source_path, destination_folder)

# %%
# !rm -r real
# !rm -r fake
# !rm -r real_vs_fake
# Out:
# rm: cannot remove 'real': No such file or directory
# rm: cannot remove 'fake': No such file or directory
# rm: cannot remove 'real_vs_fake': No such file or directory

# %%
# Specify the source folder containing subfolders with images
destination_folder = 'real'
# Specify the destination folder where images will be copied
source_folder = 'wiki'

# Call the function to copy images
copy_images(source_folder, destination_folder)

# %%
# Specify the source folder containing subfolders with images
destination_folder = 'fake'
# Specify the destination folder where images will be copied
source_folder = 'inpainting'

# Call the function to copy images
copy_images(source_folder, destination_folder)

# %%
# !mkdir real_vs_fake

# %%
import os
import shutil
import random

# Define paths
source_folder = "real"
destination_folder = "real_vs_fake"

# Create destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Create test, train, and valid folders within destination folder
folders = ['test', 'train', 'valid']
for folder in folders:
    os.makedirs(os.path.join(destination_folder, folder, 'real'), exist_ok=True)

# List all images in source folder
images = os.listdir(source_folder)
random.shuffle(images)

# Calculate the number of images for each category
total_images = len(images)
test_count = 5000
train_count = int(0.8 * (total_images - test_count))
valid_count = total_images - test_count - train_count

# Move images to respective folders
for folder, count in [('test', test_count), ('train', train_count), ('valid', valid_count)]:
    for i in range(count):
        image = images.pop()
        shutil.copy(os.path.join(source_folder, image), os.path.join(destination_folder, folder, 'real'))

# Copy train, valid, and test folders to real_vs_fake
# for folder in folders:
#     shutil.copytree(os.path.join(destination_folder, folder), os.path.join(destination_folder, 'real_vs_fake', folder))

# %%
import os
import shutil
import random

# %%
# Define paths
source_folder = "fake"
destination_folder = "real_vs_fake"

# Create destination folder if it doesn't exist
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Create test, train, and valid folders within destination folder
folders = ['test', 'train', 'valid']
for folder in folders:
    os.makedirs(os.path.join(destination_folder, folder, 'fake'), exist_ok=True)

# List all images in source folder
images = os.listdir(source_folder)
random.shuffle(images)

# Calculate the number of images for each category
total_images = len(images)
test_count = 5000
train_count = int(0.8 * (total_images - test_count))
valid_count = total_images - test_count - train_count

# Move images to respective folders
for folder, count in [('test', test_count), ('train', train_count), ('valid', valid_count)]:
    for i in range(count):
        image = images.pop()
        shutil.copy(os.path.join(source_folder, image), os.path.join(destination_folder, folder, 'fake'))

# Copy train, valid, and test folders to real_vs_fake
# for folder in folders:
#     shutil.copytree(os.path.join(destination_folder, folder), os.path.join(destination_folder, 'real_vs_fake', folder))

# %%
# !rm -r /kaggle/working/real_vs_fake
# !rm -r /kaggle/working/fake
# !rm -r /kaggle/working/real

# %%
def count_files(folder_path):
    # Initialize count
    file_count = 0

    # Walk through the folder and count files
    for _, _, files in os.walk(folder_path):
        file_count += len(files)

    return file_count

# %%
# Specify the folder path
folders = ['test', 'train', 'valid']
folder_path = 'real_vs_fake/'

for i in folders:
  print("Number of files in fake/"+str(i)+" :", count_files(folder_path+i+'/fake'))
# Out:
# Number of files in fake/test : 5000
# Number of files in fake/train : 20000
# Number of files in fake/valid : 5000

# %%
# Specify the folder path
folders = ['test', 'train', 'valid']
folder_path = 'real_vs_fake/'

for i in folders:
  print("Number of files in real/"+str(i)+" :", count_files(folder_path+i+'/real'))
# Out:
# Number of files in real/test : 5000
# Number of files in real/train : 20000
# Number of files in real/valid : 5000

# %%
import cv2
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.applications import DenseNet121, VGG16
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
import tensorflow as tf
from tqdm import tqdm

# %%
import keras

# %%
base_path = 'real_vs_fake/'
image_gen = ImageDataGenerator(rescale=1./255)

train_flow = image_gen.flow_from_directory(
    base_path + 'train/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 40000 images belonging to 2 classes.

# %%
image_gen1 = ImageDataGenerator(rescale=1./255)

valid_flow = image_gen1.flow_from_directory(
    base_path + 'valid/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 10000 images belonging to 2 classes.

# %%
image_gen1 = ImageDataGenerator(rescale=1./255.)
test_flow = image_gen.flow_from_directory(
    base_path + 'test/',
    target_size=(224, 224),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 10000 images belonging to 2 classes.

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# Number of devices: 1

# %%
def build_model(pretrained, learning_rate=0.0001):
    model = Sequential([
        pretrained,
        layers.GlobalAveragePooling2D(),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(
        loss='binary_crossentropy',
        optimizer=Adam(learning_rate=learning_rate),
        metrics=['accuracy', keras.metrics.AUC(), keras.metrics.Precision(), keras.metrics.Recall()]
    )

    return model

# %%
densenet = VGG16(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)
model = build_model(densenet)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  global_average_pooling2d_1  (None, 512)               0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 14715201 (56.13 MB)
# Trainable params: 14715201 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=5)  # Stop training if no improvement after 3 epochs
checkpoint = ModelCheckpoint('VGGImagenet.model.keras', monitor='val_loss', save_best_only=True)  # Save the best model

# %%
# !rm /kaggle/working/DenseNetNoW.keras

# %%
history = model.fit(
    train_flow,
    epochs = 5,
    validation_data =valid_flow,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/5
# 544/625 [=========================>....] - ETA: 1:04 - loss: 0.6597 - accuracy: 0.5942 - auc_1: 0.6396 - precision_1: 0.5850 - recall_1: 0.6572
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 625/625 [==============================] - 555s 877ms/step - loss: 0.6463 - accuracy: 0.6099 - auc_1: 0.6638 - precision_1: 0.5986 - recall_1: 0.6671 - val_loss: 0.5494 - val_accuracy: 0.7435 - val_auc_1: 0.8240 - val_precision_1: 0.7382 - val_recall_1: 0.7546
# Epoch 2/5
# 625/625 [==============================] - 556s 890ms/step - loss: 0.4334 - accuracy: 0.7983 - auc_1: 0.8809 - precision_1: 0.7962 - recall_1: 0.8019 - val_loss: 0.3591 - val_accuracy: 0.8413 - val_auc_1: 0.9366 - val_precision_1: 0.7903 - val_recall_1: 0.9292
# Epoch 3/5
# 625/625 [==============================] - 557s 890ms/step - loss: 0.3076 - accuracy: 0.8693 - auc_1: 0.9422 - precision_1: 0.8694 - recall_1: 0.8691 - val_loss: 0.4254 - val_accuracy: 0.8052 - val_auc_1: 0.9562 - val_precision_1: 0.9754 - val_recall_1: 0.6262
# Epoch 4/5
# 625/625 [==============================] - 554s 887ms/step - loss: 0.2116 - accuracy: 0.9131 - auc_1: 0.9726 - precision_1: 0.9131 - recall_1: 0.9131 - val_loss: 0.2259 - val_accuracy: 0.9054 - val_auc_1: 0.9761 - val_precision_1: 0.8642 - val_recall_1: 0.9620
# Epoch 5/5
# 625/625 [==============================] - 553s 885ms/step - loss: 0.1764 - accuracy: 0.9300 - auc_1: 0.9808 - precision_1: 0.9292 - recall_1: 0.9309 - val_loss: 0.1761 - val_accuracy: 0.9337 - val_auc_1: 0.9806 - val_precision_1: 0.9364 - val_recall_1: 0.9306

# %%
import pickle
with open('trainHistoryVGGImgNet.pkl', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_auc_score, f1_score, mean_absolute_error, mean_squared_error, accuracy_score

# Accuracy and loss history
plt.figure(figsize=(12, 6))

# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation precision values
plt.figure(figsize=(12, 6))
plt.plot(history.history['precision_1'])
plt.plot(history.history['val_precision_1'])
plt.title('Model precision')
plt.ylabel('Precision')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation recall values
plt.figure(figsize=(12, 6))
plt.plot(history.history['recall_1'])
plt.plot(history.history['val_recall_1'])
plt.title('Model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot training & validation AUC values
plt.figure(figsize=(12, 6))
plt.plot(history.history['auc_1'])
plt.plot(history.history['val_auc_1'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# from tensorflow.keras.models import load_model
# model2 = build_model(densenet)
# model2.compile()
# # Load the model
# model2.load_weights('/kaggle/working/DenseNetNoW.weights.h5')

# %%
# from tensorflow.keras.models import load_model


# model2 = build_model(densenet)

# # Load the model
# model2.load_weights('DenseNetImagenet.model.keras')

# %% [markdown]
# # Valid

# %%
loss, accuracy, auc, precision, recall = model.evaluate(test_flow)
# Out:
# 157/157 [==============================] - 47s 296ms/step - loss: 0.1773 - accuracy: 0.9283 - auc_1: 0.9810 - precision_1: 0.9267 - recall_1: 0.9302

# %%
# !cp -r /content/VGGImagenet.model.keras /content/drive/MyDrive/UPC/TER
