# %%
from sklearn.model_selection import train_test_split

X_test, X_val, y_test, y_val = train_test_split(X_data, y_data, test_size=0.2, random_state=42)  # Assuming X_data and y_data are your prepared features and labels

# %%
# Classification example
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)

# Regression example (assuming y_test is continuous values)
from sklearn.metrics import mean_squared_error

y_pred = model.predict(X_test)  # Make predictions on the test set
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)


print("**Evaluation Results**")
print(f"Test Loss: {loss:.4f}")  # Format loss to 4 decimal places
print(f"Test Accuracy: {accuracy:.4f}"

# %%
from tensorflow.keras.models import load_model
model2 = build_model(densenet)
model2.compile()
# # Load the model
model2.load_weights('/kaggle/working/DenseNetNoW.weights.h5')
from tensorflow.keras.models import load_model


model2 = build_model(densenet)

# # Load the model
model2.load_weights('DenseNetImagenet.model.keras')

loss, accuracy, auc, precision, recall = model.evaluate(test_flow)
